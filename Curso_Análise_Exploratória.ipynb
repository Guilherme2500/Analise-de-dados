# %% [markdown]
# # Importanto dataframes de filmes e notas e mostrando elas na tela

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
movies = pd.read_csv("movies.csv")
rate = pd.read_csv("ratings.csv")

movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
rate
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# # Olhando as notas do primeiro filme e fazendo uma média delas

# %%
rate.query("movieId==1").rating.mean()
# Out:
# 3.9209302325581397

# %% [markdown]
# # Média das notas por filme usando gráficos do seaborn e do matplotlib

# %%
media_por_filmes = rate.groupby("movieId").mean()["rating"]

# %%
sns.boxplot(media_por_filmes, orient="h")
# Out:
# <Axes: xlabel='rating'>

# %%
media_por_filmes.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: rating, dtype: float64

# %%
sns.distplot(media_por_filmes)
# Out:
# <ipython-input-7-f79cc2ad1edc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(media_por_filmes)
# <Axes: xlabel='rating', ylabel='Density'>

# %%
plt.hist(media_por_filmes)
plt.title("histograma de média dos filmes")
# Out:
# Text(0.5, 1.0, 'histograma de média dos filmes')

# %% [markdown]
# # Análise de dados de filmes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
filmes = pd.read_csv("tmdb_5000_movies.csv")
filmes.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# * Comparando os filmes com seus votos

# %%
filmes[["original_title", "vote_average"]].sort_values("vote_average", ascending=False).head(10)
# Out:
#                 original_title  vote_average
# 3519          Stiff Upper Lips          10.0
# 4247     Me You and Five Bucks          10.0
# 4045     Dancer, Texas Pop. 81          10.0
# 4662            Little Big Top          10.0
# 3992                 Sardaarji           9.5
# 2386            One Man's Hero           9.3
# 2970        There Goes My Baby           8.5
# 1881  The Shawshank Redemption           8.5
# 2796     The Prisoner of Zenda           8.4
# 3337             The Godfather           8.4

# %% [markdown]
# * Mostrando quais linguas aparecem mais

# %%
sns.catplot(x="original_language", kind="count", data=filmes)

# %% [markdown]
# # Contagem de linguas

# %%
contagem_linguas = filmes["original_language"].value_counts().to_frame().reset_index()
contagem_linguas.columns = ["original language", "total"]
contagem_linguas
# Out:
#    original language  total
# 0                 en   4505
# 1                 fr     70
# 2                 es     32
# 3                 zh     27
# 4                 de     27
# 5                 hi     19
# 6                 ja     16
# 7                 it     14
# 8                 cn     12
# 9                 ru     11
# 10                ko     11
# 11                pt      9
# 12                da      7
# 13                sv      5
# 14                nl      4
# 15                fa      4
# 16                th      3
# 17                he      3
# 18                ta      2
# 19                cs      2
# 20                ro      2
# 21                id      2
# 22                ar      2
# 23                vi      1
# 24                sl      1
# 25                ps      1
# 26                no      1
# 27                ky      1
# 28                hu      1
# 29                pl      1
# 30                af      1
# 31                nb      1
# ...

# %%
plt.pie(contagem_linguas["total"], labels=contagem_linguas["original language"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7950f0a17790>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %% [markdown]
# * Grafico não recomendado para este tipo de análise

# %% [markdown]
# #Criando novo dataframe

# %%
total = filmes["original_language"].value_counts()
total_ingles = total.loc["en"]
total_resto = total.sum() - total_ingles

new_data ={
    'lingua':['ingles', 'outros'],
    'total':[total_ingles, total_resto]
}

new_data = pd.DataFrame(new_data)
new_data

sns.barplot(x="lingua", y="total", data=new_data)
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %% [markdown]
# # Análise dos filmes que não sejam feitos em Ingles

# %%
contagem_filmes_sem_ingles = filmes.query("original_language != 'en'").original_language.value_counts()

contagem_filmes_sem_ingles.columns = ["original language", "total"]
contagem_filmes_sem_ingles
# Out:
# original_language
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# he     3
# th     3
# ro     2
# id     2
# ar     2
# cs     2
# ta     2
# tr     1
# nb     1
# af     1
# pl     1
# is     1
# hu     1
# vi     1
# ky     1
# xx     1
# te     1
# no     1
# sl     1
# ps     1
# el     1
# Name: count, dtype: int64

# %%
filmes_sem_ingles = filmes.query("original_language != 'en'")
sns.catplot(x ='original_language', kind='count',data = filmes_sem_ingles,aspect=2, order = contagem_filmes_sem_ingles.index,
            palette = 'GnBu_d')
# Out:
# <ipython-input-16-fd00c6e9c3de>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x ='original_language', kind='count',data = filmes_sem_ingles,aspect=2, order = contagem_filmes_sem_ingles.index,

# %% [markdown]
# # Tirando a média e comparando dois filmes através da dispersão dos dados

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rate.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
rate_toy_story = rate.query("movieId == 1")
rate_Jumanji = rate.query("movieId == 2")
print(len(rate_toy_story))
print(len(rate_Jumanji))
# Out:
# 215
# 110

# %%
print('Média das notas de Toy Story %.2f' % rate_toy_story.rating.mean())
# Out:
# Média das notas de Toy Story 3.92

# %%
print('Média das notas de Jumanji %.2f' % rate_Jumanji.rating.mean())
# Out:
# Média das notas de Jumanji 3.43

# %% [markdown]
# * A media não é o melhor indice para comparar a disposição de notas ou de um grande número de dados, sendo necessário um boxplot.

# %%
sns.boxplot([rate_toy_story.rating])
# Out:
# <Axes: >

# %%
sns.boxplot([rate_Jumanji.rating])
# Out:
# <Axes: >

# %% [markdown]
# * Percebe-se que em Toy Story, ocorreu um maior número de notas no intervalo de 2-4, sendo a maior ocorrencia em 4. Já em Jumanji, a maior ocorrencia acontece em 3,5, sendo que existiram notas no intervalor de 1,5. Isso mostra que Toy Story é um filmes melhor avaliado do que Jumanji

# %%
print(rate_toy_story.rating.std())
print(rate_Jumanji.rating.std())
# Out:
# 0.8348591407114045
# 0.8817134921476455

# %% [markdown]
# * O desvão padrão também é uma forma de reconhecer a distribuição daquelas notas, o que mostra se um filme está sendo bem avaliado ou não. Nesse caso, o desvio dos dois filmes é bem parecido, o que mostra uma disputa bem acirrada, apenas sendo capaz de visualizar através do gráfico.

# %%
sns.scatterplot(x='userId', y="rating", data=rate_toy_story)
# Out:
# <Axes: xlabel='userId', ylabel='rating'>

# %%
sns.scatterplot(x='userId', y="rating", data=rate_Jumanji)
# Out:
# <Axes: xlabel='userId', ylabel='rating'>
